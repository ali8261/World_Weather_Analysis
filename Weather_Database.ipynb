# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#3. Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(cities[:10], 'Generate', len(cities))
# Out:
# ['hermanus', 'kaeo', 'silopi', 'busselton', 'biltine', 'sobolevo', 'taolanaro', 'tucurui', 'jamestown', 'new castle'] Generate 761

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1953b94ecd1f162ef948121cafed5985

# %%
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | kaeo
# Processing Record 3 of Set 1 | silopi
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | biltine
# Processing Record 6 of Set 1 | sobolevo
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 8 of Set 1 | tucurui
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | new castle
# Processing Record 11 of Set 1 | chuguyevka
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | moses lake
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | tumannyy
# City not found. Skipping
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | sakakah
# Processing Record 19 of Set 1 | provost
# Processing Record 20 of Set 1 | gannan
# Processing Record 21 of Set 1 | cleethorpes
# Processing Record 22 of Set 1 | faanui
# Processing Record 23 of Set 1 | bell ville
# Processing Record 24 of Set 1 | udachnyy
# Processing Record 25 of Set 1 | cap malheureux
# Processing Record 26 of Set 1 | huarmey
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | urengoy
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | belaya gora
# Processing Record 33 of Set 1 | richards bay
# Processing Record 34 of Set 1 | avera
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | lazaro cardenas
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | mpanda
# Processing Record 42 of Set 1 | grand gaube
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 44 of Set 1 | port hueneme
# Processing Record 45 of Set 1 | tucupita
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | vung tau
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | barcelos
# Processing Record 1 of Set 2 | nabire
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | tramandai
# Processing Record 4 of Set 2 | maniitsoq
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | aykhal
# Processing Record 7 of Set 2 | valley
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | lompoc
# Processing Record 12 of Set 2 | larap
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | bentiu
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | mangrol
# Processing Record 19 of Set 2 | dunedin
# Processing Record 20 of Set 2 | hofn
# Processing Record 21 of Set 2 | esperantinopolis
# Processing Record 22 of Set 2 | esperance
# Processing Record 23 of Set 2 | lorengau
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | ghanzi
# Processing Record 26 of Set 2 | marystown
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | northam
# Processing Record 29 of Set 2 | namibe
# Processing Record 30 of Set 2 | hay river
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | kajaani
# Processing Record 33 of Set 2 | necochea
# Processing Record 34 of Set 2 | aasiaat
# Processing Record 35 of Set 2 | karatau
# Processing Record 36 of Set 2 | ponta do sol
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | nkhotakota
# Processing Record 39 of Set 2 | amderma
# City not found. Skipping
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | korcula
# Processing Record 42 of Set 2 | dharchula
# Processing Record 43 of Set 2 | talavera de la reina
# Processing Record 44 of Set 2 | krasnooktyabrskiy
# Processing Record 45 of Set 2 | agadir
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | saskylakh
# Processing Record 50 of Set 2 | kosino
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | hambantota
# Processing Record 3 of Set 3 | maimon
# City not found. Skipping
# Processing Record 4 of Set 3 | ruston
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping
# Processing Record 6 of Set 3 | samalaeulu
# City not found. Skipping
# Processing Record 7 of Set 3 | lindenhurst
# Processing Record 8 of Set 3 | teguldet
# Processing Record 9 of Set 3 | vao
# Processing Record 10 of Set 3 | isiro
# Processing Record 11 of Set 3 | barrow
# Processing Record 12 of Set 3 | kostivere
# Processing Record 13 of Set 3 | sao joao da barra
# Processing Record 14 of Set 3 | deputatskiy
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | college
# Processing Record 17 of Set 3 | labutta
# City not found. Skipping
# Processing Record 18 of Set 3 | mocoa
# Processing Record 19 of Set 3 | dingle
# Processing Record 20 of Set 3 | atar
# Processing Record 21 of Set 3 | pitimbu
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | itaituba
# Processing Record 24 of Set 3 | shitanjing
# Processing Record 25 of Set 3 | nishihara
# Processing Record 26 of Set 3 | dubovskoye
# Processing Record 27 of Set 3 | shelburne
# Processing Record 28 of Set 3 | san quintin
# Processing Record 29 of Set 3 | bubaque
# Processing Record 30 of Set 3 | virden
# Processing Record 31 of Set 3 | padang
# Processing Record 32 of Set 3 | anda
# Processing Record 33 of Set 3 | korla
# Processing Record 34 of Set 3 | cherskiy
# Processing Record 35 of Set 3 | bluff
# Processing Record 36 of Set 3 | plover
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | belushya guba
# City not found. Skipping
# Processing Record 39 of Set 3 | mwingi
# Processing Record 40 of Set 3 | qandahar
# City not found. Skipping
# Processing Record 41 of Set 3 | sri aman
# Processing Record 42 of Set 3 | yellowknife
# Processing Record 43 of Set 3 | pionerskiy
# Processing Record 44 of Set 3 | saldanha
# Processing Record 45 of Set 3 | canto do buriti
# Processing Record 46 of Set 3 | the valley
# Processing Record 47 of Set 3 | lasa
# Processing Record 48 of Set 3 | imeni poliny osipenko
# Processing Record 49 of Set 3 | lata
# Processing Record 50 of Set 3 | buin
# Processing Record 1 of Set 4 | novyy urengoy
# Processing Record 2 of Set 4 | souillac
# Processing Record 3 of Set 4 | westport
# Processing Record 4 of Set 4 | arawa
# Processing Record 5 of Set 4 | calbuco
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping
# Processing Record 7 of Set 4 | constitucion
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | kharhial
# Processing Record 10 of Set 4 | tommot
# Processing Record 11 of Set 4 | geraldton
# Processing Record 12 of Set 4 | kamenskoye
# City not found. Skipping
# Processing Record 13 of Set 4 | torbay
# Processing Record 14 of Set 4 | kazalinsk
# City not found. Skipping
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping
# Processing Record 16 of Set 4 | savannah bight
# Processing Record 17 of Set 4 | vanimo
# Processing Record 18 of Set 4 | aripuana
# Processing Record 19 of Set 4 | balkanabat
# Processing Record 20 of Set 4 | cayenne
# Processing Record 21 of Set 4 | mouzakion
# City not found. Skipping
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | port hedland
# Processing Record 24 of Set 4 | hervey bay
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | pokrovsk
# Processing Record 27 of Set 4 | andenes
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | toguchin
# Processing Record 30 of Set 4 | kasongo-lunda
# Processing Record 31 of Set 4 | marcona
# City not found. Skipping
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | surat thani
# Processing Record 34 of Set 4 | lianzhou
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | afsin
# Processing Record 37 of Set 4 | saleaula
# City not found. Skipping
# Processing Record 38 of Set 4 | severo-kurilsk
# Processing Record 39 of Set 4 | iberia
# Processing Record 40 of Set 4 | cabo san lucas
# Processing Record 41 of Set 4 | ogaminana
# Processing Record 42 of Set 4 | bakreswar
# Processing Record 43 of Set 4 | sitka
# Processing Record 44 of Set 4 | vigrestad
# Processing Record 45 of Set 4 | murray bridge
# Processing Record 46 of Set 4 | zhigansk
# Processing Record 47 of Set 4 | charleville-mezieres
# Processing Record 48 of Set 4 | hilo
# Processing Record 49 of Set 4 | olafsvik
# Processing Record 50 of Set 4 | surt
# Processing Record 1 of Set 5 | beloha
# Processing Record 2 of Set 5 | kuche
# City not found. Skipping
# Processing Record 3 of Set 5 | knysna
# Processing Record 4 of Set 5 | campos altos
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | police
# Processing Record 7 of Set 5 | broken hill
# Processing Record 8 of Set 5 | polis
# Processing Record 9 of Set 5 | portland
# Processing Record 10 of Set 5 | birin
# Processing Record 11 of Set 5 | berlevag
# Processing Record 12 of Set 5 | rocha
# Processing Record 13 of Set 5 | barentsburg
# City not found. Skipping
# Processing Record 14 of Set 5 | houma
# Processing Record 15 of Set 5 | cabinda
# Processing Record 16 of Set 5 | rolla
# Processing Record 17 of Set 5 | bintulu
# Processing Record 18 of Set 5 | eskasem
# City not found. Skipping
# Processing Record 19 of Set 5 | lashio
# Processing Record 20 of Set 5 | bridgewater
# Processing Record 21 of Set 5 | kindu
# Processing Record 22 of Set 5 | kavaratti
# Processing Record 23 of Set 5 | ekpoma
# Processing Record 24 of Set 5 | guiberoua
# Processing Record 25 of Set 5 | asadabad
# Processing Record 26 of Set 5 | san
# Processing Record 27 of Set 5 | galbshtadt
# Processing Record 28 of Set 5 | yar-sale
# Processing Record 29 of Set 5 | cidreira
# Processing Record 30 of Set 5 | fujin
# Processing Record 31 of Set 5 | waddan
# Processing Record 32 of Set 5 | cedar city
# Processing Record 33 of Set 5 | siavonga
# Processing Record 34 of Set 5 | concarneau
# Processing Record 35 of Set 5 | notodden
# Processing Record 36 of Set 5 | urumqi
# Processing Record 37 of Set 5 | hualmay
# Processing Record 38 of Set 5 | lebu
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | port macquarie
# Processing Record 41 of Set 5 | salalah
# Processing Record 42 of Set 5 | nouadhibou
# Processing Record 43 of Set 5 | mareeba
# Processing Record 44 of Set 5 | poum
# Processing Record 45 of Set 5 | dali
# Processing Record 46 of Set 5 | panji
# Processing Record 47 of Set 5 | hithadhoo
# Processing Record 48 of Set 5 | nantucket
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | whitehorse
# Processing Record 1 of Set 6 | victoria
# Processing Record 2 of Set 6 | vilyuysk
# Processing Record 3 of Set 6 | tiksi
# Processing Record 4 of Set 6 | nerchinskiy zavod
# Processing Record 5 of Set 6 | xichang
# Processing Record 6 of Set 6 | codrington
# Processing Record 7 of Set 6 | fort saint james
# Processing Record 8 of Set 6 | prieska
# Processing Record 9 of Set 6 | nortelandia
# Processing Record 10 of Set 6 | salama
# Processing Record 11 of Set 6 | iqaluit
# Processing Record 12 of Set 6 | palabuhanratu
# City not found. Skipping
# Processing Record 13 of Set 6 | ixtapa
# Processing Record 14 of Set 6 | isangel
# Processing Record 15 of Set 6 | amga
# Processing Record 16 of Set 6 | moura
# Processing Record 17 of Set 6 | deer lake
# Processing Record 18 of Set 6 | port hardy
# Processing Record 19 of Set 6 | srednekolymsk
# Processing Record 20 of Set 6 | pahalgam
# Processing Record 21 of Set 6 | sawakin
# Processing Record 22 of Set 6 | novodugino
# Processing Record 23 of Set 6 | juifang
# City not found. Skipping
# Processing Record 24 of Set 6 | ilebo
# Processing Record 25 of Set 6 | puerto escondido
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | filingue
# Processing Record 28 of Set 6 | bur gabo
# City not found. Skipping
# Processing Record 29 of Set 6 | luderitz
# Processing Record 30 of Set 6 | yinchuan
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping
# Processing Record 32 of Set 6 | zbiroh
# Processing Record 33 of Set 6 | neyshabur
# Processing Record 34 of Set 6 | dok kham tai
# Processing Record 35 of Set 6 | shingu
# Processing Record 36 of Set 6 | guerrero negro
# Processing Record 37 of Set 6 | katsuura
# Processing Record 38 of Set 6 | bara
# Processing Record 39 of Set 6 | muros
# Processing Record 40 of Set 6 | oktyabrskoye
# Processing Record 41 of Set 6 | tual
# Processing Record 42 of Set 6 | mys shmidta
# City not found. Skipping
# Processing Record 43 of Set 6 | mahajanga
# Processing Record 44 of Set 6 | tulum
# Processing Record 45 of Set 6 | tagusao
# Processing Record 46 of Set 6 | chunskiy
# Processing Record 47 of Set 6 | pilar
# Processing Record 48 of Set 6 | yakeshi
# Processing Record 49 of Set 6 | coquimbo
# Processing Record 50 of Set 6 | loukhi
# Processing Record 1 of Set 7 | kolondieba
# Processing Record 2 of Set 7 | tabou
# Processing Record 3 of Set 7 | muhos
# Processing Record 4 of Set 7 | port blair
# Processing Record 5 of Set 7 | bambous virieux
# Processing Record 6 of Set 7 | margate
# Processing Record 7 of Set 7 | azimur
# City not found. Skipping
# Processing Record 8 of Set 7 | samarai
# Processing Record 9 of Set 7 | siderno
# Processing Record 10 of Set 7 | hayden
# Processing Record 11 of Set 7 | saint-philippe
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | kavieng
# Processing Record 14 of Set 7 | saint-pierre
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | quang ngai
# Processing Record 17 of Set 7 | las vegas
# Processing Record 18 of Set 7 | yaan
# Processing Record 19 of Set 7 | sukumo
# Processing Record 20 of Set 7 | vardo
# Processing Record 21 of Set 7 | klaksvik
# Processing Record 22 of Set 7 | takoradi
# Processing Record 23 of Set 7 | sisimiut
# Processing Record 24 of Set 7 | belyy yar
# Processing Record 25 of Set 7 | santa adelia
# Processing Record 26 of Set 7 | ugoofaaru
# Processing Record 27 of Set 7 | det udom
# Processing Record 28 of Set 7 | rudraprayag
# Processing Record 29 of Set 7 | batticaloa
# Processing Record 30 of Set 7 | klyuchi
# Processing Record 31 of Set 7 | kupang
# Processing Record 32 of Set 7 | rostock
# Processing Record 33 of Set 7 | dandong
# Processing Record 34 of Set 7 | rawannawi
# City not found. Skipping
# Processing Record 35 of Set 7 | abapo
# Processing Record 36 of Set 7 | tsienyane
# City not found. Skipping
# Processing Record 37 of Set 7 | lavrentiya
# Processing Record 38 of Set 7 | broome
# Processing Record 39 of Set 7 | mosquera
# Processing Record 40 of Set 7 | pangody
# Processing Record 41 of Set 7 | polyarnyy
# Processing Record 42 of Set 7 | kiruna
# Processing Record 43 of Set 7 | yakima
# Processing Record 44 of Set 7 | beringovskiy
# Processing Record 45 of Set 7 | red bluff
# Processing Record 46 of Set 7 | lagoa
# Processing Record 47 of Set 7 | mount isa
# Processing Record 48 of Set 7 | cartagena
# Processing Record 49 of Set 7 | tuy hoa
# Processing Record 50 of Set 7 | shujaabad
# Processing Record 1 of Set 8 | nyurba
# Processing Record 2 of Set 8 | druzhba
# Processing Record 3 of Set 8 | hailar
# Processing Record 4 of Set 8 | port hawkesbury
# Processing Record 5 of Set 8 | los llanos de aridane
# Processing Record 6 of Set 8 | vila franca do campo
# Processing Record 7 of Set 8 | ca mau
# Processing Record 8 of Set 8 | ekhabi
# Processing Record 9 of Set 8 | ivanava
# Processing Record 10 of Set 8 | slavyanka
# Processing Record 11 of Set 8 | sumbe
# Processing Record 12 of Set 8 | baykit
# Processing Record 13 of Set 8 | el badari
# City not found. Skipping
# Processing Record 14 of Set 8 | asfi
# Processing Record 15 of Set 8 | louisbourg
# City not found. Skipping
# Processing Record 16 of Set 8 | tamandare
# Processing Record 17 of Set 8 | brae
# Processing Record 18 of Set 8 | itarema
# Processing Record 19 of Set 8 | ojinaga
# Processing Record 20 of Set 8 | baruun-urt
# Processing Record 21 of Set 8 | bengkulu
# Processing Record 22 of Set 8 | satitoa
# City not found. Skipping
# Processing Record 23 of Set 8 | snasa
# Processing Record 24 of Set 8 | dekoa
# City not found. Skipping
# Processing Record 25 of Set 8 | dhidhdhoo
# Processing Record 26 of Set 8 | clyde river
# Processing Record 27 of Set 8 | talcahuano
# Processing Record 28 of Set 8 | bolungarvik
# City not found. Skipping
# Processing Record 29 of Set 8 | general roca
# Processing Record 30 of Set 8 | seoul
# Processing Record 31 of Set 8 | talnakh
# Processing Record 32 of Set 8 | mindelo
# Processing Record 33 of Set 8 | phrai bung
# City not found. Skipping
# Processing Record 34 of Set 8 | caravelas
# Processing Record 35 of Set 8 | mitsamiouli
# Processing Record 36 of Set 8 | matara
# Processing Record 37 of Set 8 | itacoatiara
# Processing Record 38 of Set 8 | te anau
# Processing Record 39 of Set 8 | la palma
# Processing Record 40 of Set 8 | falealupo
# City not found. Skipping
# Processing Record 41 of Set 8 | chibuto
# Processing Record 42 of Set 8 | kendari
# Processing Record 43 of Set 8 | ntungamo
# Processing Record 44 of Set 8 | san policarpo
# Processing Record 45 of Set 8 | tabiauea
# City not found. Skipping
# Processing Record 46 of Set 8 | venado tuerto
# Processing Record 47 of Set 8 | heze
# Processing Record 48 of Set 8 | macaboboni
# City not found. Skipping
# Processing Record 49 of Set 8 | adeje
# Processing Record 50 of Set 8 | port shepstone
# Processing Record 1 of Set 9 | ayios matthaios
# City not found. Skipping
# Processing Record 2 of Set 9 | carnarvon
# Processing Record 3 of Set 9 | alta floresta
# Processing Record 4 of Set 9 | vestmannaeyjar
# Processing Record 5 of Set 9 | russell
# Processing Record 6 of Set 9 | ostrovnoy
# Processing Record 7 of Set 9 | dujuma
# City not found. Skipping
# Processing Record 8 of Set 9 | ahuimanu
# Processing Record 9 of Set 9 | vostok
# Processing Record 10 of Set 9 | ambovombe
# Processing Record 11 of Set 9 | noumea
# Processing Record 12 of Set 9 | redmond
# Processing Record 13 of Set 9 | haines junction
# Processing Record 14 of Set 9 | kikwit
# Processing Record 15 of Set 9 | narsaq
# Processing Record 16 of Set 9 | miass
# Processing Record 17 of Set 9 | ancud
# Processing Record 18 of Set 9 | sur
# Processing Record 19 of Set 9 | sabzevar
# Processing Record 20 of Set 9 | playas
# Processing Record 21 of Set 9 | leningradskiy
# Processing Record 22 of Set 9 | airai
# Processing Record 23 of Set 9 | lumberton
# Processing Record 24 of Set 9 | norilsk
# Processing Record 25 of Set 9 | stepnyak
# Processing Record 26 of Set 9 | nizhneyansk
# City not found. Skipping
# Processing Record 27 of Set 9 | conceicao do araguaia
# Processing Record 28 of Set 9 | umzimvubu
# City not found. Skipping
# Processing Record 29 of Set 9 | nuuk
# Processing Record 30 of Set 9 | khasan
# Processing Record 31 of Set 9 | pevek
# Processing Record 32 of Set 9 | vila do maio
# Processing Record 33 of Set 9 | bojnurd
# Processing Record 34 of Set 9 | milkovo
# Processing Record 35 of Set 9 | luganville
# Processing Record 36 of Set 9 | mouzouras
# Processing Record 37 of Set 9 | umm lajj
# Processing Record 38 of Set 9 | buarcos
# Processing Record 39 of Set 9 | esperantina
# Processing Record 40 of Set 9 | prata
# Processing Record 41 of Set 9 | bonoua
# Processing Record 42 of Set 9 | sechura
# Processing Record 43 of Set 9 | khowst
# Processing Record 44 of Set 9 | beterou
# Processing Record 45 of Set 9 | novoye atlashevo
# City not found. Skipping
# Processing Record 46 of Set 9 | ust-kuyga
# Processing Record 47 of Set 9 | mount gambier
# Processing Record 48 of Set 9 | las rosas
# Processing Record 49 of Set 9 | valparaiso
# Processing Record 50 of Set 9 | palasbari
# Processing Record 1 of Set 10 | roma
# Processing Record 2 of Set 10 | mitchell
# Processing Record 3 of Set 10 | lanigan
# Processing Record 4 of Set 10 | carikar
# City not found. Skipping
# Processing Record 5 of Set 10 | malakal
# Processing Record 6 of Set 10 | laon
# Processing Record 7 of Set 10 | porto walter
# Processing Record 8 of Set 10 | kirakira
# Processing Record 9 of Set 10 | vavoua
# Processing Record 10 of Set 10 | buenos aires
# Processing Record 11 of Set 10 | seydi
# Processing Record 12 of Set 10 | hibbing
# Processing Record 13 of Set 10 | marawi
# Processing Record 14 of Set 10 | kaduqli
# Processing Record 15 of Set 10 | champerico
# Processing Record 16 of Set 10 | serowe
# Processing Record 17 of Set 10 | long xuyen
# Processing Record 18 of Set 10 | yamada
# Processing Record 19 of Set 10 | suntar
# Processing Record 20 of Set 10 | san cristobal
# Processing Record 21 of Set 10 | missoula
# Processing Record 22 of Set 10 | ambon
# Processing Record 23 of Set 10 | port-cartier
# Processing Record 24 of Set 10 | acapulco
# Processing Record 25 of Set 10 | camacupa
# Processing Record 26 of Set 10 | pisco
# Processing Record 27 of Set 10 | lagos
# Processing Record 28 of Set 10 | hohhot
# Processing Record 29 of Set 10 | zaraza
# Processing Record 30 of Set 10 | arlit
# Processing Record 31 of Set 10 | kopervik
# Processing Record 32 of Set 10 | grindavik
# Processing Record 33 of Set 10 | khani
# Processing Record 34 of Set 10 | samusu
# City not found. Skipping
# Processing Record 35 of Set 10 | krasnoselkup
# Processing Record 36 of Set 10 | yingkou
# Processing Record 37 of Set 10 | dalbandin
# Processing Record 38 of Set 10 | bargal
# City not found. Skipping
# Processing Record 39 of Set 10 | okhotsk
# Processing Record 40 of Set 10 | morehead
# Processing Record 41 of Set 10 | little current
# Processing Record 42 of Set 10 | buraydah
# Processing Record 43 of Set 10 | olinda
# Processing Record 44 of Set 10 | baker city
# Processing Record 45 of Set 10 | praia
# Processing Record 46 of Set 10 | maturin
# Processing Record 47 of Set 10 | nemuro
# Processing Record 48 of Set 10 | arman
# Processing Record 49 of Set 10 | monteagudo
# Processing Record 50 of Set 10 | zyryanka
# Processing Record 1 of Set 11 | velur
# Processing Record 2 of Set 11 | maldonado
# Processing Record 3 of Set 11 | bethlehem
# Processing Record 4 of Set 11 | sao miguel do oeste
# City not found. Skipping
# Processing Record 5 of Set 11 | henderson
# Processing Record 6 of Set 11 | sangar
# Processing Record 7 of Set 11 | pangnirtung
# Processing Record 8 of Set 11 | faya
# Processing Record 9 of Set 11 | kaduna
# Processing Record 10 of Set 11 | hamilton
# Processing Record 11 of Set 11 | kusye-aleksandrovskiy
# City not found. Skipping
# Processing Record 12 of Set 11 | paamiut
# Processing Record 13 of Set 11 | la pintada
# Processing Record 14 of Set 11 | tarquinia
# Processing Record 15 of Set 11 | vaitupu
# City not found. Skipping
# Processing Record 16 of Set 11 | nhulunbuy
# Processing Record 17 of Set 11 | romodanovo
# Processing Record 18 of Set 11 | batemans bay
# Processing Record 19 of Set 11 | diego de almagro
# Processing Record 20 of Set 11 | annau
# Processing Record 21 of Set 11 | anadyr
# Processing Record 22 of Set 11 | tevriz
# Processing Record 23 of Set 11 | papara
# Processing Record 24 of Set 11 | samarinda
# Processing Record 25 of Set 11 | pacific grove
# Processing Record 26 of Set 11 | shiyan
# Processing Record 27 of Set 11 | presidencia roque saenz pena
# Processing Record 28 of Set 11 | alofi
# Processing Record 29 of Set 11 | adrar
# Processing Record 30 of Set 11 | gao
# Processing Record 31 of Set 11 | sambava
# Processing Record 32 of Set 11 | lethem
# Processing Record 33 of Set 11 | djambala
# Processing Record 34 of Set 11 | zomba
# Processing Record 35 of Set 11 | kinsale
# Processing Record 36 of Set 11 | hami
# Processing Record 37 of Set 11 | lydenburg
# Processing Record 38 of Set 11 | meulaboh
# Processing Record 39 of Set 11 | anamur
# Processing Record 40 of Set 11 | koshurnikovo
# Processing Record 41 of Set 11 | fort nelson
# Processing Record 42 of Set 11 | plettenberg bay
# Processing Record 43 of Set 11 | maumere
# Processing Record 44 of Set 11 | aldan
# Processing Record 45 of Set 11 | garden city
# Processing Record 46 of Set 11 | ratnagiri
# Processing Record 47 of Set 11 | la asuncion
# Processing Record 48 of Set 11 | sergeyevka
# Processing Record 49 of Set 11 | cabedelo
# Processing Record 50 of Set 11 | yangjiang
# Processing Record 1 of Set 12 | xinzhou
# Processing Record 2 of Set 12 | sataua
# City not found. Skipping
# Processing Record 3 of Set 12 | melipilla
# Processing Record 4 of Set 12 | quatre cocos
# Processing Record 5 of Set 12 | wenling
# Processing Record 6 of Set 12 | cam ranh
# Processing Record 7 of Set 12 | phayao
# Processing Record 8 of Set 12 | channel-port aux basques
# Processing Record 9 of Set 12 | tabialan
# City not found. Skipping
# Processing Record 10 of Set 12 | znamenskoye
# Processing Record 11 of Set 12 | dunmore town
# Processing Record 12 of Set 12 | jawa
# Processing Record 13 of Set 12 | adana
# Processing Record 14 of Set 12 | khorixas
# Processing Record 15 of Set 12 | kenora
# Processing Record 16 of Set 12 | soligalich
# Processing Record 17 of Set 12 | mahon
# Processing Record 18 of Set 12 | roald
# Processing Record 19 of Set 12 | whyalla
# Processing Record 20 of Set 12 | saint-augustin
# Processing Record 21 of Set 12 | qazvin
# Processing Record 22 of Set 12 | dehloran
# Processing Record 23 of Set 12 | fairbanks
# Processing Record 24 of Set 12 | palmer
# Processing Record 25 of Set 12 | aranjuez
# Processing Record 26 of Set 12 | walvis bay
# Processing Record 27 of Set 12 | laguna
# Processing Record 28 of Set 12 | dakar
# Processing Record 29 of Set 12 | waingapu
# Processing Record 30 of Set 12 | lolua
# City not found. Skipping
# Processing Record 31 of Set 12 | touros
# Processing Record 32 of Set 12 | kandra
# Processing Record 33 of Set 12 | novo aripuana
# Processing Record 34 of Set 12 | kalia
# Processing Record 35 of Set 12 | yeppoon
# Processing Record 36 of Set 12 | sehithwa
# Processing Record 37 of Set 12 | pierre
# Processing Record 38 of Set 12 | amurzet
# Processing Record 39 of Set 12 | paveh
# Processing Record 40 of Set 12 | matata
# Processing Record 41 of Set 12 | cintalapa
# Processing Record 42 of Set 12 | ohringen
# Processing Record 43 of Set 12 | tuatapere
# Processing Record 44 of Set 12 | husavik
# Processing Record 45 of Set 12 | belogorsk
# Processing Record 46 of Set 12 | bilibino
# Processing Record 47 of Set 12 | katangli
# Processing Record 48 of Set 12 | uvat
# Processing Record 49 of Set 12 | gatton
# Processing Record 50 of Set 12 | aliwal north
# Processing Record 1 of Set 13 | tessalit
# Processing Record 2 of Set 13 | ngukurr
# City not found. Skipping
# Processing Record 3 of Set 13 | moroni
# Processing Record 4 of Set 13 | maceio
# Processing Record 5 of Set 13 | ketchikan
# Processing Record 6 of Set 13 | jasper
# Processing Record 7 of Set 13 | yerazgavors
# Processing Record 8 of Set 13 | khagrachari
# City not found. Skipping
# Processing Record 9 of Set 13 | tateyama
# Processing Record 10 of Set 13 | fort saint john
# City not found. Skipping
# Processing Record 11 of Set 13 | oranjemund
# Processing Record 12 of Set 13 | fandriana
# Processing Record 13 of Set 13 | san patricio
# Processing Record 14 of Set 13 | grand-lahou
# Processing Record 15 of Set 13 | victor harbor
# Processing Record 16 of Set 13 | bom jesus
# Processing Record 17 of Set 13 | srbac
# Processing Record 18 of Set 13 | saint george
# Processing Record 19 of Set 13 | ribeira brava
# Processing Record 20 of Set 13 | bierun
# Processing Record 21 of Set 13 | tayoltita
# Processing Record 22 of Set 13 | constantine
# Processing Record 23 of Set 13 | sokol
# Processing Record 24 of Set 13 | spencer
# Processing Record 25 of Set 13 | lac du bonnet
# Processing Record 26 of Set 13 | le port
# Processing Record 27 of Set 13 | tura
# Processing Record 28 of Set 13 | campbell river
# Processing Record 29 of Set 13 | puerto carreno
# Processing Record 30 of Set 13 | comodoro rivadavia
# Processing Record 31 of Set 13 | gat
# Processing Record 32 of Set 13 | iwaki
# Processing Record 33 of Set 13 | santa cruz
# Processing Record 34 of Set 13 | puerto madryn
# Processing Record 35 of Set 13 | sumen
# City not found. Skipping
# Processing Record 36 of Set 13 | havre-saint-pierre
# Processing Record 37 of Set 13 | dubbo
# Processing Record 38 of Set 13 | kamina
# Processing Record 39 of Set 13 | hastings
# Processing Record 40 of Set 13 | kenai
# Processing Record 41 of Set 13 | itoman
# Processing Record 42 of Set 13 | kulhudhuffushi
# Processing Record 43 of Set 13 | vila velha
# Processing Record 44 of Set 13 | saint-leu
# Processing Record 45 of Set 13 | bonavista
# Processing Record 46 of Set 13 | cabatuan
# Processing Record 47 of Set 13 | severnyy-kospashskiy
# Processing Record 48 of Set 13 | the pas
# Processing Record 49 of Set 13 | zhanatas
# City not found. Skipping
# Processing Record 50 of Set 13 | namatanai
# Processing Record 1 of Set 14 | sabang
# Processing Record 2 of Set 14 | shimoda
# Processing Record 3 of Set 14 | pemangkat
# Processing Record 4 of Set 14 | miri
# Processing Record 5 of Set 14 | aksarka
# Processing Record 6 of Set 14 | konstantinovka
# Processing Record 7 of Set 14 | gigmoto
# Processing Record 8 of Set 14 | yasugi
# Processing Record 9 of Set 14 | anloga
# Processing Record 10 of Set 14 | tiznit
# Processing Record 11 of Set 14 | ballina
# Processing Record 12 of Set 14 | auki
# Processing Record 13 of Set 14 | syracuse
# Processing Record 14 of Set 14 | labuhan
# Processing Record 15 of Set 14 | pandelys
# City not found. Skipping
# Processing Record 16 of Set 14 | gisborne
# Processing Record 17 of Set 14 | mayor pablo lagerenza
# Processing Record 18 of Set 14 | mwinilunga
# Processing Record 19 of Set 14 | tapaua
# City not found. Skipping
# Processing Record 20 of Set 14 | tshikapa
# Processing Record 21 of Set 14 | mandalgovi
# Processing Record 22 of Set 14 | mustasaari
# Processing Record 23 of Set 14 | payson
# Processing Record 24 of Set 14 | waipawa
# Processing Record 25 of Set 14 | beau vallon
# Processing Record 26 of Set 14 | aketi
# Processing Record 27 of Set 14 | colomi
# Processing Record 28 of Set 14 | rorvik
# Processing Record 29 of Set 14 | tautira
# Processing Record 30 of Set 14 | porto novo
# Processing Record 31 of Set 14 | malwan
# City not found. Skipping
# Processing Record 32 of Set 14 | praya
# Processing Record 33 of Set 14 | tabas
# Processing Record 34 of Set 14 | chuzhou
# Processing Record 35 of Set 14 | evensk
# Processing Record 36 of Set 14 | mayo
# Processing Record 37 of Set 14 | sorland
# Processing Record 38 of Set 14 | chokwe
# Processing Record 39 of Set 14 | navalmoral de la mata
# Processing Record 40 of Set 14 | asyut
# Processing Record 41 of Set 14 | kaitangata
# Processing Record 42 of Set 14 | hongjiang
# Processing Record 43 of Set 14 | novobirilyussy
# Processing Record 44 of Set 14 | garissa
# Processing Record 45 of Set 14 | katobu
# Processing Record 46 of Set 14 | rio de jesus
# Processing Record 47 of Set 14 | wamba
# Processing Record 48 of Set 14 | tsabong
# Processing Record 49 of Set 14 | muzquiz
# City not found. Skipping
# Processing Record 50 of Set 14 | iquitos
# Processing Record 1 of Set 15 | nachingwea
# Processing Record 2 of Set 15 | cairo
# Processing Record 3 of Set 15 | sicuani
# Processing Record 4 of Set 15 | skelleftea
# Processing Record 5 of Set 15 | saint-georges
# Processing Record 6 of Set 15 | bertoua
# Processing Record 7 of Set 15 | nalut
# Processing Record 8 of Set 15 | moose factory
# Processing Record 9 of Set 15 | makakilo city
# Processing Record 10 of Set 15 | mwene-ditu
# Processing Record 11 of Set 15 | igarka
# Processing Record 12 of Set 15 | ahipara
# Processing Record 13 of Set 15 | clarence town
# Processing Record 14 of Set 15 | sidi bu zayd
# City not found. Skipping
# Processing Record 15 of Set 15 | shieli
# Processing Record 16 of Set 15 | chernyshevskiy
# Processing Record 17 of Set 15 | chotila
# Processing Record 18 of Set 15 | svetlogorsk
# Processing Record 19 of Set 15 | tungkang
# City not found. Skipping
# Processing Record 20 of Set 15 | havelock
# Processing Record 21 of Set 15 | pajapan
# Processing Record 22 of Set 15 | iskateley
# Processing Record 23 of Set 15 | jumla
# Processing Record 24 of Set 15 | zandvoort
# Processing Record 25 of Set 15 | tidore
# City not found. Skipping
# Processing Record 26 of Set 15 | abengourou
# Processing Record 27 of Set 15 | peremyshl
# Processing Record 28 of Set 15 | utiroa
# City not found. Skipping
# Processing Record 29 of Set 15 | methoni
# Processing Record 30 of Set 15 | uinskoye
# Processing Record 31 of Set 15 | bandarbeyla
# Processing Record 32 of Set 15 | cuenca
# Processing Record 33 of Set 15 | piacabucu
# Processing Record 34 of Set 15 | gondar
# Processing Record 35 of Set 15 | maragogi
# Processing Record 36 of Set 15 | cockburn town
# Processing Record 37 of Set 15 | bitlis
# Processing Record 38 of Set 15 | jiwani
# Processing Record 39 of Set 15 | poso
# Processing Record 40 of Set 15 | durban
# Processing Record 41 of Set 15 | sao borja
# Processing Record 42 of Set 15 | gambela
# Processing Record 43 of Set 15 | bose
# Processing Record 44 of Set 15 | kununurra
# Processing Record 45 of Set 15 | tres arroyos
# Processing Record 46 of Set 15 | shirokiy
# Processing Record 47 of Set 15 | kyabe
# Processing Record 48 of Set 15 | burkhala
# City not found. Skipping
# Processing Record 49 of Set 15 | kutum
# Processing Record 50 of Set 15 | basco
# Processing Record 1 of Set 16 | nueva loja
# Processing Record 2 of Set 16 | atambua
# Processing Record 3 of Set 16 | senneterre
# Processing Record 4 of Set 16 | dalvik
# Processing Record 5 of Set 16 | terrace bay
# Processing Record 6 of Set 16 | murgab
# Processing Record 7 of Set 16 | diamantino
# Processing Record 8 of Set 16 | kampene
# Processing Record 9 of Set 16 | mana
# Processing Record 10 of Set 16 | srivardhan
# Processing Record 11 of Set 16 | abu samrah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
# Reorder the columns
city_data_df=city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Hermanus      ZA -34.4187   19.2345     63.00        86         100
# 1       Kaeo      NZ -35.1000  173.7833     56.75        82          92
# 2     Silopi      TR  37.2497   42.4694     73.40        31          75
# 3  Busselton      AU -33.6500  115.3333     52.00        97         100
# 4    Biltine      TD  14.5333   20.9167     90.07        23          99
#
#    Wind Speed Current Description
# 0        3.00     overcast clouds
# 1        3.83     overcast clouds
# 2       12.66       broken clouds
# 3        4.36     overcast clouds
# 4        5.32     overcast clouds

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("data/WeatherPy_Database.csv", index_label="City ID")
